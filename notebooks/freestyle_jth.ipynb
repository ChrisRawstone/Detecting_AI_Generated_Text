# %%
import pandas as pd 

generated_essays = pd.DataFrame()
# concat all generated essays
for i in range(1,6):
    generated_essays = pd.concat([generated_essays, pd.read_csv("../data/raw/generated_data/AI_Generated_df{}.csv".format(i))])
generated_essays = generated_essays.rename(columns={"generated_text":"text"})

# get the original essays
original_essays = pd.read_csv("../data/raw/train_essays.csv")
original_essays.drop(columns=["id"], inplace=True)

# concat the two dataframes
df = pd.concat([original_essays, generated_essays])
df.reset_index(inplace=True, drop=True)
# create key from index
df["key"] = df.index

# %%
df.reset_index(drop=True)
# Out:
#       prompt_id                                               text  generated  \
# 0           0.0  Cars. Cars have been around since they became ...        0.0
# 1           0.0  Transportation is a large necessity in most co...        0.0
# 2           0.0  "America's love affair with it's vehicles seem...        0.0
# 3           0.0  How often do you ride in a car? Do you drive a...        0.0
# 4           0.0  Cars are a wonderful thing. They are perhaps o...        0.0
# ...         ...                                                ...        ...
# 2714        1.0  The Electoral College, a system established by...        1.0
# 2715        1.0  Furthermore, the Electoral College ensures tha...        1.0
# 2716        1.0  percent of the popular vote, yet still lost be...        1.0
# 2717        1.0  Furthermore, the Electoral College system is f...        1.0
# 2718        1.0  The Electoral College, despite its flaws, has ...        1.0
#
#        key
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ...    ...
# 2714  2714
# 2715  2715
# 2716  2716
# 2717  2717
# 2718  2718
#
# [2719 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(df[['text','generated']], test_size=0.2, random_state=42)

# %%
X_train
# Out:
#                                                    text  generated
# 2381  In addition to the environmental benefits and ...        1.0
# 695   Advantages of limiting car usage? Is that even...        0.0
# 1407  One of the major advantages of limiting car us...        1.0
# 445   There can be many advantages and disadvantages...        0.0
# 998   Ah, the electoral college. Don't you just how ...        0.0
# ...                                                 ...        ...
# 1638  In conclusion, reducing car use can have a pro...        1.0
# 1095  People all over the world are saying goodbye t...        0.0
# 1130  Dear state senator, I believe that we shouldn'...        0.0
# 1294  The modern automobile has been the axle to the...        0.0
# 860   The Electoral College is a process that should...        0.0
#
# [2175 rows x 2 columns]
